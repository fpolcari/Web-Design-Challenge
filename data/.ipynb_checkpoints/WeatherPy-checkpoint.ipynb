# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in /Users/fanniepolcari/opt/anaconda3/lib/python3.9/site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in /Users/fanniepolcari/opt/anaconda3/lib/python3.9/site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations (will use numpy for random lats & lngs)
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 598

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={weather_api_key}"

# list of city data
city_data = []

# create counters
record_count = 1
set_count = 1

# loop through all the cities in our list
for i, city in enumerate(cities):
    
    # group the cities in sets of 50 for logging purposes
    if(i % 50 == 0 and i >= 50):
        # reset the group every 50 counts of cities
        set_count += 1
        record_count = 1
        
    # create the endpoint url for each city
    city_url = f"{url}&q={city}"
    
    # log the city of group and the set number
    print(f"Processing city #{record_count} in group#{set_count} | {city}")
    record_count += 1
    
    try:
        # run API requests and retrieve the data
        city_weather = requests.get(city_url).json()
        
        # add a time delay to avoid blowing out the API key
        time.sleep(2)
        
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]
        
        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
        
    except:
        # if an error occurs when making the API all, skip the city
        print(f"{city} has an error. Skipping...")
        pass
    
# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing city #1 in group#1 | albany
# Processing city #2 in group#1 | shelburne
# Processing city #3 in group#1 | faanui
# Processing city #4 in group#1 | bredasdorp
# Processing city #5 in group#1 | luce
# Processing city #6 in group#1 | lahad datu
# Processing city #7 in group#1 | green river
# Processing city #8 in group#1 | lebu
# Processing city #9 in group#1 | atuona
# Processing city #10 in group#1 | anadyr
# Processing city #11 in group#1 | verkhnetulomskiy
# Processing city #12 in group#1 | hobart
# Processing city #13 in group#1 | mys shmidta
# mys shmidta has an error. Skipping...
# Processing city #14 in group#1 | new norfolk
# Processing city #15 in group#1 | port elizabeth
# Processing city #16 in group#1 | ushuaia
# Processing city #17 in group#1 | mahebourg
# Processing city #18 in group#1 | ust-tsilma
# Processing city #19 in group#1 | margate
# Processing city #20 in group#1 | oswego
# Processing city #21 in group#1 | sainte-marie
# Processing city #22 in group#1 | arraial do cabo
# Processing city #23 in group#1 | ponta do sol
# Processing city #24 in group#1 | palmer
# Processing city #25 in group#1 | naze
# Processing city #26 in group#1 | illoqqortoormiut
# illoqqortoormiut has an error. Skipping...
# Processing city #27 in group#1 | pevek
# Processing city #28 in group#1 | iqaluit
# Processing city #29 in group#1 | yellowknife
# Processing city #30 in group#1 | ribeira grande
# Processing city #31 in group#1 | bluff
# Processing city #32 in group#1 | rikitea
# Processing city #33 in group#1 | punta arenas
# Processing city #34 in group#1 | nosy varika
# Processing city #35 in group#1 | tura
# Processing city #36 in group#1 | den helder
# Processing city #37 in group#1 | jamestown
# Processing city #38 in group#1 | hamilton
# Processing city #39 in group#1 | cherskiy
# Processing city #40 in group#1 | lavrentiya
# Processing city #41 in group#1 | bulaevo
# Processing city #42 in group#1 | vaini
# Processing city #43 in group#1 | kaitangata
# Processing city #44 in group#1 | chute-aux-outardes
# Processing city #45 in group#1 | hasaki
# Processing city #46 in group#1 | mentok
# mentok has an error. Skipping...
# Processing city #47 in group#1 | dois corregos
# Processing city #48 in group#1 | busselton
# Processing city #49 in group#1 | san patricio
# Processing city #50 in group#1 | puerto ayacucho
# Processing city #1 in group#2 | avarua
# Processing city #2 in group#2 | shimoda
# Processing city #3 in group#2 | nikolskoye
# Processing city #4 in group#2 | tuktoyaktuk
# Processing city #5 in group#2 | mataura
# Processing city #6 in group#2 | gizo
# Processing city #7 in group#2 | santa isabel
# Processing city #8 in group#2 | sao jose de ribamar
# Processing city #9 in group#2 | kavieng
# Processing city #10 in group#2 | paragominas
# Processing city #11 in group#2 | new richmond
# Processing city #12 in group#2 | kualakapuas
# Processing city #13 in group#2 | east london
# Processing city #14 in group#2 | kapaa
# Processing city #15 in group#2 | flinders
# Processing city #16 in group#2 | kautokeino
# Processing city #17 in group#2 | lasa
# Processing city #18 in group#2 | belushya guba
# belushya guba has an error. Skipping...
# Processing city #19 in group#2 | great falls
# Processing city #20 in group#2 | provideniya
# Processing city #21 in group#2 | longyearbyen
# Processing city #22 in group#2 | portland
# Processing city #23 in group#2 | waipawa
# Processing city #24 in group#2 | bambous virieux
# Processing city #25 in group#2 | georgetown
# Processing city #26 in group#2 | severo-kurilsk
# Processing city #27 in group#2 | castro
# Processing city #28 in group#2 | geraldton
# Processing city #29 in group#2 | cidreira
# Processing city #30 in group#2 | umzimvubu
# umzimvubu has an error. Skipping...
# Processing city #31 in group#2 | kuche
# kuche has an error. Skipping...
# Processing city #32 in group#2 | hermanus
# Processing city #33 in group#2 | camacha
# Processing city #34 in group#2 | springbok
# Processing city #35 in group#2 | beihai
# Processing city #36 in group#2 | butaritari
# Processing city #37 in group#2 | umba
# Processing city #38 in group#2 | husavik
# Processing city #39 in group#2 | puerto ayora
# Processing city #40 in group#2 | hilo
# Processing city #41 in group#2 | khatanga
# Processing city #42 in group#2 | palabuhanratu
# palabuhanratu has an error. Skipping...
# Processing city #43 in group#2 | vikhorevka
# Processing city #44 in group#2 | kruisfontein
# Processing city #45 in group#2 | whitehorse
# Processing city #46 in group#2 | mpanda
# Processing city #47 in group#2 | mehamn
# Processing city #48 in group#2 | kidal
# Processing city #49 in group#2 | tsihombe
# tsihombe has an error. Skipping...
# Processing city #50 in group#2 | vryheid
# Processing city #1 in group#3 | amderma
# amderma has an error. Skipping...
# Processing city #2 in group#3 | saskylakh
# Processing city #3 in group#3 | kieta
# Processing city #4 in group#3 | qaanaaq
# Processing city #5 in group#3 | tasiilaq
# Processing city #6 in group#3 | kulhudhuffushi
# Processing city #7 in group#3 | manokwari
# Processing city #8 in group#3 | amurzet
# Processing city #9 in group#3 | barentsburg
# barentsburg has an error. Skipping...
# Processing city #10 in group#3 | vanderhoof
# Processing city #11 in group#3 | deputatskiy
# Processing city #12 in group#3 | los llanos de aridane
# Processing city #13 in group#3 | atar
# Processing city #14 in group#3 | zhezkazgan
# Processing city #15 in group#3 | kalengwa
# Processing city #16 in group#3 | artyk
# artyk has an error. Skipping...
# Processing city #17 in group#3 | victoria
# Processing city #18 in group#3 | omboue
# Processing city #19 in group#3 | sentyabrskiy
# sentyabrskiy has an error. Skipping...
# Processing city #20 in group#3 | pontarlier
# Processing city #21 in group#3 | conceicao do araguaia
# Processing city #22 in group#3 | airai
# Processing city #23 in group#3 | tiksi
# Processing city #24 in group#3 | berlevag
# Processing city #25 in group#3 | kodiak
# Processing city #26 in group#3 | amatlan
# amatlan has an error. Skipping...
# Processing city #27 in group#3 | skibbereen
# Processing city #28 in group#3 | tabiauea
# tabiauea has an error. Skipping...
# Processing city #29 in group#3 | cagayan de tawi-tawi
# cagayan de tawi-tawi has an error. Skipping...
# Processing city #30 in group#3 | mosquera
# Processing city #31 in group#3 | marcona
# marcona has an error. Skipping...
# Processing city #32 in group#3 | maine-soroa
# Processing city #33 in group#3 | candawaga
# candawaga has an error. Skipping...
# Processing city #34 in group#3 | lilongwe
# Processing city #35 in group#3 | atambua
# Processing city #36 in group#3 | bolshaya rechka
# Processing city #37 in group#3 | namibe
# Processing city #38 in group#3 | klaksvik
# Processing city #39 in group#3 | qaqortoq
# Processing city #40 in group#3 | aksarka
# Processing city #41 in group#3 | upernavik
# Processing city #42 in group#3 | chicama
# Processing city #43 in group#3 | carnarvon
# Processing city #44 in group#3 | saryshagan
# saryshagan has an error. Skipping...
# Processing city #45 in group#3 | vaitupu
# vaitupu has an error. Skipping...
# Processing city #46 in group#3 | pochutla
# Processing city #47 in group#3 | wanaka
# Processing city #48 in group#3 | tottori
# Processing city #49 in group#3 | verkhnevilyuysk
# Processing city #50 in group#3 | saint-pierre
# Processing city #1 in group#4 | ibotirama
# Processing city #2 in group#4 | cape town
# Processing city #3 in group#4 | korla
# Processing city #4 in group#4 | cabo san lucas
# Processing city #5 in group#4 | luderitz
# Processing city #6 in group#4 | ribas do rio pardo
# Processing city #7 in group#4 | malwan
# malwan has an error. Skipping...
# Processing city #8 in group#4 | dungarpur
# Processing city #9 in group#4 | kismayo
# Processing city #10 in group#4 | coquimbo
# Processing city #11 in group#4 | chuy
# Processing city #12 in group#4 | port alfred
# Processing city #13 in group#4 | mariani
# Processing city #14 in group#4 | bandarbeyla
# Processing city #15 in group#4 | lorengau
# Processing city #16 in group#4 | taolanaro
# taolanaro has an error. Skipping...
# Processing city #17 in group#4 | presidencia roque saenz pena
# Processing city #18 in group#4 | hithadhoo
# Processing city #19 in group#4 | dali
# Processing city #20 in group#4 | khash
# Processing city #21 in group#4 | bilma
# Processing city #22 in group#4 | gamboma
# Processing city #23 in group#4 | ballina
# Processing city #24 in group#4 | joaquim nabuco
# Processing city #25 in group#4 | hami
# Processing city #26 in group#4 | grand gaube
# Processing city #27 in group#4 | tuatapere
# Processing city #28 in group#4 | lagoa
# Processing city #29 in group#4 | lethem
# Processing city #30 in group#4 | okhotsk
# Processing city #31 in group#4 | magadan
# Processing city #32 in group#4 | malayal
# Processing city #33 in group#4 | sokolo
# Processing city #34 in group#4 | kaeo
# Processing city #35 in group#4 | udachnyy
# Processing city #36 in group#4 | seoul
# Processing city #37 in group#4 | bara
# Processing city #38 in group#4 | blytheville
# Processing city #39 in group#4 | marawi
# Processing city #40 in group#4 | eden
# Processing city #41 in group#4 | jieshi
# Processing city #42 in group#4 | tomatlan
# Processing city #43 in group#4 | bakonyszentlaszlo
# Processing city #44 in group#4 | strezhevoy
# Processing city #45 in group#4 | chapais
# Processing city #46 in group#4 | mezhevoy
# Processing city #47 in group#4 | shitanjing
# Processing city #48 in group#4 | kearney
# Processing city #49 in group#4 | bengkulu
# Processing city #50 in group#4 | vanavara
# Processing city #1 in group#5 | codrington
# Processing city #2 in group#5 | bontang
# Processing city #3 in group#5 | oranjemund
# Processing city #4 in group#5 | siguiri
# Processing city #5 in group#5 | sangmelima
# Processing city #6 in group#5 | raychikhinsk
# Processing city #7 in group#5 | vila
# Processing city #8 in group#5 | dingle
# Processing city #9 in group#5 | vestmannaeyjar
# Processing city #10 in group#5 | the valley
# Processing city #11 in group#5 | newark
# Processing city #12 in group#5 | saldanha
# Processing city #13 in group#5 | mar del plata
# Processing city #14 in group#5 | yerofey pavlovich
# Processing city #15 in group#5 | saint-philippe
# Processing city #16 in group#5 | waidhofen
# Processing city #17 in group#5 | ancud
# Processing city #18 in group#5 | vrangel
# Processing city #19 in group#5 | killybegs
# Processing city #20 in group#5 | saint anthony
# Processing city #21 in group#5 | luwingu
# Processing city #22 in group#5 | naryan-mar
# Processing city #23 in group#5 | saint george
# Processing city #24 in group#5 | lompoc
# Processing city #25 in group#5 | mount isa
# Processing city #26 in group#5 | la ronge
# Processing city #27 in group#5 | solenzo
# Processing city #28 in group#5 | pangnirtung
# Processing city #29 in group#5 | tecoanapa
# Processing city #30 in group#5 | soyo
# Processing city #31 in group#5 | konza
# Processing city #32 in group#5 | nuuk
# Processing city #33 in group#5 | ryotsu
# Processing city #34 in group#5 | kavaratti
# Processing city #35 in group#5 | burnie
# Processing city #36 in group#5 | tigil
# Processing city #37 in group#5 | sangueya
# Processing city #38 in group#5 | keelung
# Processing city #39 in group#5 | gallup
# Processing city #40 in group#5 | hvide sande
# Processing city #41 in group#5 | alofi
# Processing city #42 in group#5 | kondopoga
# Processing city #43 in group#5 | norman wells
# Processing city #44 in group#5 | manggar
# Processing city #45 in group#5 | avera
# Processing city #46 in group#5 | sakaiminato
# Processing city #47 in group#5 | kloulklubed
# Processing city #48 in group#5 | attawapiskat
# attawapiskat has an error. Skipping...
# Processing city #49 in group#5 | constantine
# Processing city #50 in group#5 | malanje
# Processing city #1 in group#6 | chama
# Processing city #2 in group#6 | buraydah
# Processing city #3 in group#6 | fortuna
# Processing city #4 in group#6 | dehloran
# Processing city #5 in group#6 | awbari
# Processing city #6 in group#6 | polson
# Processing city #7 in group#6 | jining
# Processing city #8 in group#6 | paciran
# Processing city #9 in group#6 | puerto carreno
# Processing city #10 in group#6 | talnakh
# Processing city #11 in group#6 | shieli
# Processing city #12 in group#6 | bonthe
# Processing city #13 in group#6 | sitka
# Processing city #14 in group#6 | samusu
# samusu has an error. Skipping...
# Processing city #15 in group#6 | sao joao da barra
# Processing city #16 in group#6 | pyinmana
# Processing city #17 in group#6 | imbituba
# Processing city #18 in group#6 | kathu
# Processing city #19 in group#6 | sawakin
# Processing city #20 in group#6 | mahanoro
# Processing city #21 in group#6 | dakar
# Processing city #22 in group#6 | moranbah
# Processing city #23 in group#6 | oussouye
# Processing city #24 in group#6 | san quintin
# Processing city #25 in group#6 | colares
# Processing city #26 in group#6 | ilulissat
# Processing city #27 in group#6 | jabiru
# jabiru has an error. Skipping...
# Processing city #28 in group#6 | virginia beach
# Processing city #29 in group#6 | touros
# Processing city #30 in group#6 | bethel
# Processing city #31 in group#6 | bargal
# bargal has an error. Skipping...
# Processing city #32 in group#6 | fare
# Processing city #33 in group#6 | surt
# Processing city #34 in group#6 | barrow
# Processing city #35 in group#6 | basingstoke
# Processing city #36 in group#6 | mulchen
# Processing city #37 in group#6 | altamont
# Processing city #38 in group#6 | chokurdakh
# Processing city #39 in group#6 | pisco
# Processing city #40 in group#6 | olafsvik
# Processing city #41 in group#6 | wake forest
# Processing city #42 in group#6 | antofagasta
# Processing city #43 in group#6 | sergeyevka
# Processing city #44 in group#6 | ciudad bolivar
# Processing city #45 in group#6 | smirnykh
# Processing city #46 in group#6 | general roca
# Processing city #47 in group#6 | la baule-escoublac
# Processing city #48 in group#6 | diego de almagro
# Processing city #49 in group#6 | moscow
# Processing city #50 in group#6 | nhulunbuy
# Processing city #1 in group#7 | saleaula
# saleaula has an error. Skipping...
# Processing city #2 in group#7 | salinas
# Processing city #3 in group#7 | nacala
# Processing city #4 in group#7 | pinheiro machado
# Processing city #5 in group#7 | masjed-e soleyman
# masjed-e soleyman has an error. Skipping...
# Processing city #6 in group#7 | general pico
# Processing city #7 in group#7 | khambi-irze
# Processing city #8 in group#7 | sri aman
# Processing city #9 in group#7 | iranshahr
# Processing city #10 in group#7 | ruteng
# Processing city #11 in group#7 | huarmey
# Processing city #12 in group#7 | mglin
# Processing city #13 in group#7 | tam ky
# Processing city #14 in group#7 | lulea
# Processing city #15 in group#7 | artemisa
# Processing city #16 in group#7 | nemuro
# Processing city #17 in group#7 | tutoia
# Processing city #18 in group#7 | aklavik
# Processing city #19 in group#7 | bata
# Processing city #20 in group#7 | la palma
# Processing city #21 in group#7 | xining
# Processing city #22 in group#7 | peachland
# Processing city #23 in group#7 | nizwa
# Processing city #24 in group#7 | barentu
# Processing city #25 in group#7 | acajutla
# Processing city #26 in group#7 | mount gambier
# Processing city #27 in group#7 | shimanovsk
# Processing city #28 in group#7 | crossville
# Processing city #29 in group#7 | sorland
# Processing city #30 in group#7 | tulle
# Processing city #31 in group#7 | mujiayingzi
# Processing city #32 in group#7 | nome
# Processing city #33 in group#7 | nizhneyansk
# nizhneyansk has an error. Skipping...
# Processing city #34 in group#7 | labatlan
# Processing city #35 in group#7 | suntar
# Processing city #36 in group#7 | sobolevo
# Processing city #37 in group#7 | richards bay
# Processing city #38 in group#7 | olinda
# Processing city #39 in group#7 | muros
# Processing city #40 in group#7 | vryburg
# Processing city #41 in group#7 | isangel
# Processing city #42 in group#7 | namatanai
# Processing city #43 in group#7 | shache
# Processing city #44 in group#7 | spas
# Processing city #45 in group#7 | vila franca do campo
# Processing city #46 in group#7 | utica
# Processing city #47 in group#7 | ulverstone
# Processing city #48 in group#7 | zhigansk
# Processing city #49 in group#7 | gravdal
# Processing city #50 in group#7 | port hedland
# Processing city #1 in group#8 | chiang rai
# Processing city #2 in group#8 | dustlik
# Processing city #3 in group#8 | lixourion
# Processing city #4 in group#8 | ballarat
# Processing city #5 in group#8 | ahipara
# Processing city #6 in group#8 | taoudenni
# Processing city #7 in group#8 | dikson
# Processing city #8 in group#8 | esperance
# Processing city #9 in group#8 | ayios kirikos
# ayios kirikos has an error. Skipping...
# Processing city #10 in group#8 | saint stephen
# Processing city #11 in group#8 | palana
# Processing city #12 in group#8 | doha
# Processing city #13 in group#8 | mnogovershinnyy
# Processing city #14 in group#8 | leningradskiy
# Processing city #15 in group#8 | palu
# Processing city #16 in group#8 | ulaangom
# Processing city #17 in group#8 | yulara
# Processing city #18 in group#8 | bereznik
# Processing city #19 in group#8 | shubarkuduk
# Processing city #20 in group#8 | pak phanang
# Processing city #21 in group#8 | narsaq
# Processing city #22 in group#8 | port lincoln
# Processing city #23 in group#8 | manasa
# Processing city #24 in group#8 | ratnagiri
# Processing city #25 in group#8 | taretan
# Processing city #26 in group#8 | tortoli
# Processing city #27 in group#8 | akyab
# Processing city #28 in group#8 | zhuhai
# Processing city #29 in group#8 | nanortalik
# Processing city #30 in group#8 | kapit
# Processing city #31 in group#8 | torbay
# Processing city #32 in group#8 | mukhen
# Processing city #33 in group#8 | vao
# Processing city #34 in group#8 | cayenne
# Processing city #35 in group#8 | tumannyy
# tumannyy has an error. Skipping...
# Processing city #36 in group#8 | ixtapa
# Processing city #37 in group#8 | hobyo
# Processing city #38 in group#8 | rupert
# Processing city #39 in group#8 | bathsheba
# Processing city #40 in group#8 | beloha
# Processing city #41 in group#8 | jasper
# Processing city #42 in group#8 | sorong
# Processing city #43 in group#8 | salalah
# Processing city #44 in group#8 | wageningen
# Processing city #45 in group#8 | grand centre
# grand centre has an error. Skipping...
# Processing city #46 in group#8 | toyooka
# Processing city #47 in group#8 | nishihara
# Processing city #48 in group#8 | opobo
# opobo has an error. Skipping...
# Processing city #49 in group#8 | milos
# Processing city #50 in group#8 | senanga
# Processing city #1 in group#9 | siva
# Processing city #2 in group#9 | itarema
# Processing city #3 in group#9 | marabba
# Processing city #4 in group#9 | louisbourg
# louisbourg has an error. Skipping...
# Processing city #5 in group#9 | saint-augustin
# Processing city #6 in group#9 | addi ugri
# addi ugri has an error. Skipping...
# Processing city #7 in group#9 | tarko-sale
# Processing city #8 in group#9 | aleksandrov gay
# Processing city #9 in group#9 | burica
# burica has an error. Skipping...
# Processing city #10 in group#9 | jiddah
# jiddah has an error. Skipping...
# Processing city #11 in group#9 | gidam
# Processing city #12 in group#9 | sambava
# Processing city #13 in group#9 | broken hill
# Processing city #14 in group#9 | harper
# Processing city #15 in group#9 | nilai
# Processing city #16 in group#9 | solnechnyy
# Processing city #17 in group#9 | burns lake
# Processing city #18 in group#9 | xichang
# Processing city #19 in group#9 | warqla
# warqla has an error. Skipping...
# Processing city #20 in group#9 | piranhas
# Processing city #21 in group#9 | andros town
# Processing city #22 in group#9 | batemans bay
# Processing city #23 in group#9 | bolu
# Processing city #24 in group#9 | ivaipora
# Processing city #25 in group#9 | brigantine
# Processing city #26 in group#9 | baglung
# Processing city #27 in group#9 | belyy yar
# Processing city #28 in group#9 | misratah
# Processing city #29 in group#9 | kudahuvadhoo
# Processing city #30 in group#9 | olavarria
# Processing city #31 in group#9 | katsuura
# Processing city #32 in group#9 | karaton
# Processing city #33 in group#9 | bomet
# Processing city #34 in group#9 | sept-iles
# Processing city #35 in group#9 | bereda
# Processing city #36 in group#9 | albion
# Processing city #37 in group#9 | bakaly
# Processing city #38 in group#9 | xuanhua
# Processing city #39 in group#9 | upington
# Processing city #40 in group#9 | thompson
# Processing city #41 in group#9 | walvis bay
# Processing city #42 in group#9 | marsa matruh
# Processing city #43 in group#9 | taltal
# Processing city #44 in group#9 | amapa
# Processing city #45 in group#9 | arkul
# Processing city #46 in group#9 | nazarovo
# Processing city #47 in group#9 | marzuq
# Processing city #48 in group#9 | jumla
# Processing city #49 in group#9 | tilichiki
# Processing city #50 in group#9 | chivay
# Processing city #1 in group#10 | hambantota
# Processing city #2 in group#10 | baruun-urt
# Processing city #3 in group#10 | saint-leu
# Processing city #4 in group#10 | santa fe
# Processing city #5 in group#10 | egvekinot
# Processing city #6 in group#10 | dzilam gonzalez
# Processing city #7 in group#10 | date
# Processing city #8 in group#10 | aranos
# Processing city #9 in group#10 | khandbari
# Processing city #10 in group#10 | brae
# Processing city #11 in group#10 | moengo
# Processing city #12 in group#10 | bojnurd
# Processing city #13 in group#10 | melton
# Processing city #14 in group#10 | praia
# Processing city #15 in group#10 | ghanzi
# Processing city #16 in group#10 | wakkanai
# Processing city #17 in group#10 | yeppoon
# Processing city #18 in group#10 | aguadilla
# Processing city #19 in group#10 | bolobo
# Processing city #20 in group#10 | nouadhibou
# Processing city #21 in group#10 | ambilobe
# Processing city #22 in group#10 | bougouni
# Processing city #23 in group#10 | sarkand
# Processing city #24 in group#10 | broome
# Processing city #25 in group#10 | gongzhuling
# Processing city #26 in group#10 | port hardy
# Processing city #27 in group#10 | grand river south east
# grand river south east has an error. Skipping...
# Processing city #28 in group#10 | moa
# Processing city #29 in group#10 | luganville
# Processing city #30 in group#10 | ojinaga
# Processing city #31 in group#10 | deming
# Processing city #32 in group#10 | dwarka
# Processing city #33 in group#10 | rockland
# Processing city #34 in group#10 | gat
# Processing city #35 in group#10 | mackay
# Processing city #36 in group#10 | morehead
# Processing city #37 in group#10 | miguel hidalgo
# Processing city #38 in group#10 | almaznyy
# Processing city #39 in group#10 | yaan
# Processing city #40 in group#10 | seymchan
# Processing city #41 in group#10 | leeton
# Processing city #42 in group#10 | van
# Processing city #43 in group#10 | kyren
# Processing city #44 in group#10 | asau
# Processing city #45 in group#10 | bobonong
# bobonong has an error. Skipping...
# Processing city #46 in group#10 | carballo
# Processing city #47 in group#10 | rustenburg
# Processing city #48 in group#10 | kumbhraj
# Processing city #49 in group#10 | yerbogachen
# Processing city #50 in group#10 | saint-joseph
# Processing city #1 in group#11 | sabang
# Processing city #2 in group#11 | mandali
# Processing city #3 in group#11 | ambon
# Processing city #4 in group#11 | tocopilla
# Processing city #5 in group#11 | hovd
# Processing city #6 in group#11 | lolua
# lolua has an error. Skipping...
# Processing city #7 in group#11 | mirnyy
# Processing city #8 in group#11 | kankon
# Processing city #9 in group#11 | constitucion
# Processing city #10 in group#11 | kaz
# Processing city #11 in group#11 | batagay
# Processing city #12 in group#11 | japura
# Processing city #13 in group#11 | visby
# Processing city #14 in group#11 | port shepstone
# Processing city #15 in group#11 | xai-xai
# Processing city #16 in group#11 | jacareacanga
# Processing city #17 in group#11 | souillac
# Processing city #18 in group#11 | barletta
# Processing city #19 in group#11 | ostrovnoy
# Processing city #20 in group#11 | umm lajj
# Processing city #21 in group#11 | oktyabrskoye
# Processing city #22 in group#11 | melville
# Processing city #23 in group#11 | basar
# Processing city #24 in group#11 | abu kamal
# Processing city #25 in group#11 | umm bab
# Processing city #26 in group#11 | pontianak
# Processing city #27 in group#11 | camargo
# Processing city #28 in group#11 | dunedin
# Processing city #29 in group#11 | sola
# Processing city #30 in group#11 | canitas
# canitas has an error. Skipping...
# Processing city #31 in group#11 | vestmanna
# Processing city #32 in group#11 | darhan
# Processing city #33 in group#11 | guerrero negro
# Processing city #34 in group#11 | eldorado
# Processing city #35 in group#11 | moerai
# Processing city #36 in group#11 | filingue
# Processing city #37 in group#11 | haines junction
# Processing city #38 in group#11 | ponta delgada
# Processing city #39 in group#11 | isabela
# Processing city #40 in group#11 | maple creek
# Processing city #41 in group#11 | sioux lookout
# Processing city #42 in group#11 | sistranda
# Processing city #43 in group#11 | aswan
# Processing city #44 in group#11 | novocheremshansk
# Processing city #45 in group#11 | willmar
# Processing city #46 in group#11 | anloga
# Processing city #47 in group#11 | bira
# Processing city #48 in group#11 | panjab
# Processing city #49 in group#11 | lazarev
# Processing city #50 in group#11 | turayf
# Processing city #1 in group#12 | viedma
# Processing city #2 in group#12 | ngukurr
# ngukurr has an error. Skipping...
# Processing city #3 in group#12 | beringovskiy
# Processing city #4 in group#12 | halifax
# Processing city #5 in group#12 | padang
# Processing city #6 in group#12 | wulanhaote
# wulanhaote has an error. Skipping...
# Processing city #7 in group#12 | srednekolymsk
# Processing city #8 in group#12 | alpen
# Processing city #9 in group#12 | sudak
# Processing city #10 in group#12 | kambove
# Processing city #11 in group#12 | angoche
# Processing city #12 in group#12 | fairview
# Processing city #13 in group#12 | mumford
# Processing city #14 in group#12 | arona
# Processing city #15 in group#12 | severnyy
# Processing city #16 in group#12 | partenit
# Processing city #17 in group#12 | polur
# Processing city #18 in group#12 | zhanatas
# zhanatas has an error. Skipping...
# Processing city #19 in group#12 | merauke
# Processing city #20 in group#12 | gomel
# Processing city #21 in group#12 | maniago
# Processing city #22 in group#12 | beyneu
# Processing city #23 in group#12 | tobol
# Processing city #24 in group#12 | progreso
# Processing city #25 in group#12 | acapulco
# Processing city #26 in group#12 | santo tomas
# Processing city #27 in group#12 | duz
# duz has an error. Skipping...
# Processing city #28 in group#12 | el viejo
# Processing city #29 in group#12 | preobrazheniye
# Processing city #30 in group#12 | diamantino
# Processing city #31 in group#12 | okha
# Processing city #32 in group#12 | mayskiy
# Processing city #33 in group#12 | port talbot
# Processing city #34 in group#12 | dovers
# Processing city #35 in group#12 | birjand
# Processing city #36 in group#12 | te anau
# Processing city #37 in group#12 | wanning
# Processing city #38 in group#12 | odweyne
# Processing city #39 in group#12 | ulaanbaatar
# Processing city #40 in group#12 | biak
# Processing city #41 in group#12 | batticaloa
# Processing city #42 in group#12 | tunduru
# tunduru has an error. Skipping...
# Processing city #43 in group#12 | coihaique
# Processing city #44 in group#12 | baltatesti
# Processing city #45 in group#12 | eenhana
# Processing city #46 in group#12 | vizinga
# Processing city #47 in group#12 | leh
# Processing city #48 in group#12 | kharp
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_data_pd = pd.DataFrame(city_data)
city_data_pd.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      albany  42.6001  -73.9662     74.39        92          97        1.01
# 1   shelburne  44.0787  -80.2041     66.24        64          87        6.44
# 2      faanui -16.4833 -151.7500     77.54        76         100       20.62
# 3  bredasdorp -34.5322   20.0403     60.19        69           0        9.71
# 4        luce  48.4369    1.4636     78.55        59          99        6.24
#
#   Country        Date
# 0      US  1663084152
# 1      CA  1663084423
# 2      PF  1663084426
# 3      ZA  1663084428
# 4      FR  1663084431

# %%
city_data_pd.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  552.000000  552.000000  552.000000  552.000000  552.000000  552.000000
# mean    20.410442   24.109157   67.250743   69.273551   57.507246    7.712264
# std     33.399693   88.955977   16.507563   22.753380   39.769480    5.184050
# min    -54.800000 -179.166700   27.880000    7.000000    0.000000    0.000000
# 25%     -7.118700  -53.536000   54.355000   60.000000   15.000000    4.000000
# 50%     25.609900   27.880400   70.905000   75.000000   74.500000    6.910000
# 75%     47.932175  102.269050   78.837500   86.000000   99.000000   10.085000
# max     78.218600  179.316700  112.100000  100.000000  100.000000   32.770000
#
#                Date
# count  5.520000e+02
# mean   1.663085e+09
# std    4.081310e+02
# min    1.663084e+09
# 25%    1.663085e+09
# 50%    1.663085e+09
# 75%    1.663085e+09
# max    1.663086e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Get the indices of cities that have humidity over 100%
dirty_city_data = city_data_pd[(city_data_pd["Humidity"] > 100)].index

print(dirty_city_data)
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data = city_data_pd.drop(dirty_city_data, inplace=False)
clean_city_data.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      albany  42.6001  -73.9662     74.39        92          97        1.01
# 1   shelburne  44.0787  -80.2041     66.24        64          87        6.44
# 2      faanui -16.4833 -151.7500     77.54        76         100       20.62
# 3  bredasdorp -34.5322   20.0403     60.19        69           0        9.71
# 4        luce  48.4369    1.4636     78.55        59          99        6.24
#
#   Country        Date
# 0      US  1663084152
# 1      CA  1663084423
# 2      PF  1663084426
# 3      ZA  1663084428
# 4      FR  1663084431

# %%
# Extract relevant fields from the data frame
lats = clean_city_data["Lat"]
max_temps = clean_city_data["Max Temp"]
humidity = clean_city_data["Humidity"]
cloudiness = clean_city_data["Cloudiness"]
wind_speed = clean_city_data["Wind Speed"]

# Export the City_Data into a csv
clean_city_data.to_csv(output_data_file, index_label="City_ID")

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
import seaborn as sns
sns.set
# Out:
# <function seaborn.rcmod.set(*args, **kwargs)>

# %%
f = plt.figure(facecolor=(1, 1, 1), figsize=(11.118, 7.65))

plt.scatter(lats, max_temps, edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure
plt.savefig("../images/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
f = plt.figure(facecolor=(1, 1, 1), figsize=(11.118, 7.65))

plt.scatter(lats, humidity, edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure
plt.savefig("../images/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
f = plt.figure(facecolor=(1, 1, 1), figsize=(11.118, 7.65))

plt.scatter(lats, cloudiness, edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure
plt.savefig("../images/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
f = plt.figure(facecolor=(1, 1, 1), figsize=(11.118, 7.65))

plt.scatter(lats, wind_speed, edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure
plt.savefig("../images/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# Create a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, title, text_coordinates):
    
    # run a regression on the hemisphere
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    # Plot 
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, "r-")
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.xlabel('Latitude')
    plt.ylabel(title)
    print(f"The r-value is: {rvalue**2}")
    plt.show()

# %%
# Create Northern and Southern Hemisphere Dataframes
northern_hemi_df = city_data_pd.loc[(city_data_pd["Lat"] >= 0)]
southern_hemi_df = city_data_pd.loc[(city_data_pd["Lat"] < 0)]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, 'Max Temp', (6,45))
# Out:
# The r-value is: 0.4969101214618367

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, 'Max Temp', (-55,85))
# Out:
# The r-value is: 0.6814403368297192

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, 'Humidity', (45,20))
# Out:
# The r-value is: 0.0031603631763265547

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, 'Humidity', (-50,30))
# Out:
# The r-value is: 0.016339573213077104

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, 'Cloudiness', (45,20))
# Out:
# The r-value is: 0.005995962167205208

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, 'Cloudiness', (-55,20))
# Out:
# The r-value is: 0.002675992386963467

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, 'Wind Speed', (6,28))
# Out:
# The r-value is: 0.009422720263058465

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, 'Wind Speed', (-53,17))
# Out:
# The r-value is: 0.003214138297916542
